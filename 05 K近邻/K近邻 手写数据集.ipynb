# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
digits=datasets.load_digits()

# %%
X=digits['data']

# %%
X.shape
# Out:
# (1797, 64)

# %%
y=digits['target']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
KNN_classifier=KNeighborsClassifier(n_neighbors=5)

# %%
KNN_classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
KNN_classifier.score(X_train,y_train)
# Out:
# 0.9895615866388309

# %%
KNN_classifier.score(X_test,y_test)
# Out:
# 0.9916666666666667

# %%
preclass=KNN_classifier.predict(X_test)
preclass
# Out:
# array([3, 1, 7, 4, 9, 6, 0, 7, 4, 8, 2, 4, 6, 7, 9, 4, 9, 7, 0, 2, 7, 0,
#        9, 0, 6, 8, 8, 4, 9, 0, 7, 7, 2, 5, 1, 8, 5, 9, 0, 4, 0, 0, 7, 6,
#        5, 1, 8, 1, 4, 1, 4, 6, 5, 8, 6, 5, 8, 3, 3, 1, 4, 8, 9, 7, 0, 2,
#        9, 8, 5, 8, 6, 7, 7, 5, 9, 1, 9, 7, 4, 6, 2, 2, 6, 9, 8, 2, 8, 6,
#        0, 0, 2, 8, 0, 1, 9, 3, 3, 9, 9, 8, 7, 6, 5, 0, 6, 5, 2, 5, 2, 8,
#        5, 7, 5, 1, 2, 5, 0, 2, 4, 0, 9, 3, 7, 2, 0, 9, 5, 1, 9, 5, 1, 3,
#        1, 1, 9, 9, 9, 6, 2, 0, 5, 1, 7, 7, 1, 2, 1, 9, 8, 3, 1, 0, 7, 5,
#        6, 7, 4, 4, 0, 1, 0, 9, 2, 0, 7, 4, 9, 0, 5, 4, 6, 3, 2, 3, 8, 7,
#        0, 2, 2, 4, 3, 5, 5, 0, 0, 2, 1, 1, 0, 1, 5, 1, 7, 0, 5, 9, 3, 2,
#        0, 8, 6, 6, 1, 8, 7, 8, 2, 4, 5, 0, 2, 7, 2, 6, 2, 4, 3, 2, 4, 0,
#        7, 2, 4, 5, 5, 2, 7, 4, 1, 8, 4, 7, 4, 4, 8, 7, 6, 6, 7, 6, 5, 5,
#        1, 6, 4, 4, 8, 1, 4, 9, 4, 3, 4, 5, 1, 8, 0, 0, 6, 2, 1, 1, 3, 5,
#        2, 7, 8, 2, 0, 6, 3, 9, 3, 4, 1, 7, 4, 7, 9, 2, 3, 9, 6, 9, 5, 9,
# ...

# %%
y_test
# Out:
# array([3, 1, 7, 4, 9, 6, 0, 7, 4, 8, 2, 4, 6, 7, 9, 4, 9, 7, 0, 2, 7, 0,
#        9, 0, 6, 8, 8, 4, 9, 0, 7, 7, 2, 5, 1, 8, 5, 9, 0, 4, 0, 0, 7, 6,
#        5, 1, 8, 1, 4, 1, 4, 6, 5, 8, 6, 5, 8, 3, 3, 1, 4, 8, 9, 7, 0, 2,
#        9, 8, 5, 8, 6, 7, 7, 5, 9, 1, 9, 7, 4, 6, 2, 2, 6, 9, 8, 2, 8, 6,
#        0, 0, 2, 8, 0, 1, 9, 3, 3, 9, 9, 8, 7, 6, 5, 0, 6, 5, 2, 5, 2, 8,
#        5, 7, 5, 1, 2, 5, 0, 2, 4, 0, 9, 3, 7, 2, 0, 9, 3, 1, 9, 5, 1, 3,
#        1, 1, 9, 9, 9, 6, 2, 0, 5, 1, 7, 7, 1, 2, 1, 9, 8, 3, 1, 0, 7, 5,
#        6, 7, 4, 4, 0, 1, 0, 9, 2, 0, 7, 4, 9, 0, 5, 4, 6, 3, 2, 3, 8, 7,
#        0, 2, 2, 4, 3, 5, 5, 0, 0, 2, 1, 1, 0, 1, 5, 1, 7, 0, 5, 9, 3, 2,
#        0, 8, 6, 6, 1, 8, 7, 8, 2, 4, 5, 0, 2, 7, 2, 6, 2, 4, 3, 2, 4, 0,
#        7, 2, 4, 5, 5, 2, 7, 4, 1, 8, 4, 7, 4, 4, 8, 7, 6, 6, 7, 6, 5, 5,
#        1, 6, 4, 4, 3, 1, 4, 9, 4, 3, 4, 5, 1, 8, 0, 0, 6, 2, 1, 1, 3, 5,
#        2, 7, 8, 2, 0, 6, 3, 9, 3, 4, 1, 7, 4, 7, 9, 2, 3, 9, 6, 9, 5, 9,
# ...

# %%
y_test==preclass
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
np.sum(y_test!=preclass)
# Out:
# 3

# %%
index=[]
for i in range(len(y_test)):
    if y_test[i]!=preclass[i]:
        index.append(i)
index
# Out:
# [126, 246, 334]

# %%
plt.imshow(X_test[126].reshape(8,8))

# %%
fig,a=plt.subplots(1,3)
for i in range(3):
    a[i].imshow(X_test[index[0]].reshape(8,8))
    a[i].set_title('predict:{},groundtruth:{}'.format(preclass[index[i]],y_test[index[i]]))
plt.tight_layout()
