# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('diabetes.csv') #导入文件

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neighbors=np.arange(1,9)
#train_acc=[]
#test_acc=[]
train_acc=np.empty(len(neighbors))
test_acc=np.empty(len(neighbors))

# %%
for k in neighbors:
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    #train_acc.append(knn.score(X_train,y_train))
    train_acc[k-1]=knn.score(X_train,y_train)
    test_acc[k-1]=knn.score(X_test,y_test)

# %%
train_acc
# Out:
# array([1.        , 0.84171322, 0.83240223, 0.80260708, 0.80446927,
#        0.79329609, 0.79515829, 0.80074488])

# %%
test_acc
# Out:
# array([0.67099567, 0.70562771, 0.7012987 , 0.70562771, 0.6969697 ,
#        0.72727273, 0.70995671, 0.73160173])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(X_test,y_test)
